# %%
import pandas as pd
import psycopg2

connection = psycopg2.connect("dbname=Teleco user=postgres password=Leul@123")

# Create a cursor object to interact with the database
cursor = connection.cursor()

# Query the data
query = "SELECT * FROM xdr_data"

# Load data into a pandas DataFrame
df = pd.read_sql_query(query, connection)

# print(df.columns)

# Print the number of missing values in each column
print(df.isnull().sum())
# 2. Handle Missing Values
# Option 1: Fill Missing Values
# •	Replace missing values with a default value (e.g., 0, the mean, or median of the column):

# Replace all NaN with 0
df = df.fillna(0)  # Replace all NaN with 0
# df = df.fillna(df.mean())  # Replace with column means
print(df.isnull().sum())
# Out:
# C:\Users\Almazt\AppData\Local\Temp\ipykernel_18124\2740391288.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN                                        1066
# IMEI                                           572
# Last Location Name                            1153
# RTTdl                                        27829
# RTTul                                        27812
# ...
